# %% [markdown]
# # Test Document AI

# %%
"""GCP: Contains functions that connect to Google Cloud Document AI."""

from google.cloud import documentai


docai_client = documentai.DocumentProcessorServiceClient()

with open('/Users/anapreciado/Desktop/github_repos/porygon-legaldoc-cuad/data/01_discharge_summary.pdf', "rb") as f:
    document = f.read()

def process_document(
    document: bytes,
    mime_type: str = "application/pdf",
    project_id: str="porygon-legaldoc-cuad",
    location: str="us",
    processor_id: str="e5822741a51eeb33",
) -> documentai.Document:
    """Sends a raw document to a Document AI processor and returns the result.

    Args:
        project_id: GCP project ID.
        location: Processor location (e.g. "us" or "eu").
        processor_id: The ID of the pre-trained processor to use.
        document: Raw bytes of the document.
        mime_type: MIME type of the document (e.g. "application/pdf", "image/png").

    Returns:
        A Document AI Document proto containing the extracted text and layout.
    """
    processor_name = docai_client.processor_path(project_id, location, processor_id)
    raw_document = documentai.RawDocument(content=document, mime_type=mime_type)
    request = documentai.ProcessRequest(name=processor_name, raw_document=raw_document)
    result = docai_client.process_document(request=request)
    return result.document
# Out:
# I0418 08:03:36.967098 13589274 ev_poll_posix.cc:593] FD from fork parent still in poll list: fd(90, generation: 1)

# %%
result = process_document(document = document)

# %%
result.text
# Out:
# 'CITY GENERAL HOSPITAL\nDepartment of Internal Medicine\nDISCHARGE SUMMARY\nPatient Name:\nMargaret A. Thornton\nMRN:\nDate of Birth:\nMarch 14, 1958 (Age 66)\nSSN:\nCGH-2024-087341\n523-78-4901\nAddress:\n1482 Birchwood Lane, Columbus, OH 43215 Phone:\n(614) 555-0192\nInsurance:\nBlueCross BlueShield #BCB-4421098\nPolicy Holder DOB: March 14, 1958\nAdmission Date:\nJanuary 8, 2025\nDischarge Date:\nJanuary 14, 2025\nAttending Physician: Dr. Rajesh Patel, MD\nNPI:\n1234567890\nPRIMARY DIAGNOSIS\nAcute exacerbation of congestive heart failure (CHF), EF 35%, with associated acute kidney injury (AKI),\nStage 1.\nSECONDARY DIAGNOSES\n• Type 2 diabetes mellitus, poorly controlled (HbA1c 9.2%)\n• Hypertension, Stage 2\n• Atrial fibrillation, chronic\n• Hyperlipidemia\nHISTORY OF PRESENT ILLNESS\nMs. Margaret Thornton, a 66-year-old female with a known history of CHF and Type 2 diabetes, presented\nto the Emergency Department on January 8, 2025 via EMS after her husband, Robert Thornton, called 911\nreporting acute shortness of breath and bilateral lower-extremity edema that had worsened over three days.\nOn arrival, her blood pressure was 178/102 mmHg, heart rate 112 bpm (irregularly irregular), respiratory rate\n26/min, and O2 saturation 88% on room air. She was placed on supplemental oxygen and transferred to the\nCardiac Care Unit for monitoring and aggressive diuresis.\nHOSPITAL COURSE\nThe patient was initiated on IV furosemide 80 mg twice daily with close monitoring of renal function.\nCreatinine on admission was 1.9 mg/dL (baseline 1.1 mg/dL), consistent with AKI Stage 1 in the setting of\nreduced cardiac output. Cardiology was consulted; echocardiogram confirmed EF of 35% with global\nhypokinesis. Metformin was held given AKI. Insulin sliding scale was implemented for glycemic control. By\nDay 3, urine output improved significantly and creatinine trended to 1.2 mg/dL. The patient was transitioned\nto oral torsemide 40 mg daily on Day 4. She was discharged ambulatory, breathing comfortably on room air\nwith a weight loss of 4.8 kg from admission weight.\nDISCHARGE MEDICATIONS\nMedication\nDose\nRoute\nFrequency\nTorsemide\n40 mg\nOral\nOnce daily\nCarvedilol\n6.25 mg\nOral\nTwice daily\nLisinopril\n5 mg\nOral\nOnce daily\nApixaban\n5 mg\nOral\nTwice daily\nAtorvastatin\n40 mg\nOral\nOnce nightly\nInsulin Glargine\n18 units\nSubcutaneous\nBedtime\nFOLLOW-UP INSTRUCTIONS\nMs. Thornton is instructed to follow up with Dr. Patel at City General Cardiology Clinic within 7 days of\ndischarge. She should weigh herself daily and report a weight gain of more than 2 lbs in 24 hours or 5 lbs in\none week. She was counseled on a 2g sodium diet and fluid restriction to 1.5 L/day. Endocrinology referral\nplaced for outpatient insulin optimization. Emergency contact on file: Robert Thornton (husband), (614)\n555-0847.\nElectronically signed by: Dr. Rajesh Patel, MD - January 14, 2025 | NPI: 1234567890\n'
